# %% [markdown]
# <a href="https://colab.research.google.com/github/vegaFDaniel/ChallengeTiendaAlura/blob/main/ChallengeCompleto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/alura-es-cursos/challenge1-data-science-latam.git
# %cd challenge1-data-science-latam
# !ls
# %cd base-de-datos-challenge1-latam
# !ls
# Out:
# Cloning into 'challenge1-data-science-latam'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 10 (delta 3), reused 3 (delta 3), pack-reused 2 (from 1)
# Receiving objects: 100% (10/10), 171.26 KiB | 1.22 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/challenge1-data-science-latam
# AluraStoreLatam.ipynb  base-de-datos-challenge1-latam
# /content/challenge1-data-science-latam/base-de-datos-challenge1-latam
# 'tienda_1 .csv'   tienda_2.csv	 tienda_3.csv   tienda_4.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# OJO: este tiene un espacio en el nombre, lo corregimos así
df_tienda1 = pd.read_csv('tienda_1 .csv')
df_tienda2 = pd.read_csv('tienda_2.csv')
df_tienda3 = pd.read_csv('tienda_3.csv')
df_tienda4 = pd.read_csv('tienda_4.csv')

# Mostramos las primeras filas de cada uno para confirmar que se cargaron bien
print("📊 Tienda 1:")
display(df_tienda1.head())

print("📊 Tienda 2:")
display(df_tienda2.head())

print("📊 Tienda 3:")
display(df_tienda3.head())

print("📊 Tienda 4:")
display(df_tienda4.head())
# Out:
# 📊 Tienda 1:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
ingresos = {}  # Creamos un diccionario vacío para guardar los ingresos por tienda

for i in range(1, 5):  # Bucle que recorre desde 1 hasta 4 (porque tienes tiendas 1 a 4)
    df = globals()[f'df_tienda{i}']  # Usa el nombre de la variable df_tienda1, df_tienda2, etc.
    ingresos[f'Tienda {i}'] = df['Precio'].sum()  # Calcula el ingreso total y lo guarda en el diccionario

# Mostrar los resultados formateados
for tienda, ingreso in ingresos.items():
    print(f'🛒 Ingreso total {tienda}: ${ingreso:,.2f}')
# Out:
# 🛒 Ingreso total Tienda 1: $1,150,880,400.00
# 🛒 Ingreso total Tienda 2: $1,116,343,500.00
# 🛒 Ingreso total Tienda 3: $1,098,019,600.00
# 🛒 Ingreso total Tienda 4: $1,038,375,700.00

# %%
# Encuentra la tienda con mayor ingreso
tienda_top = max(ingresos, key=ingresos.get)
ingreso_top = ingresos[tienda_top]

# Muestra el resultado
print(f'🏆 La tienda con mayor ingreso es {tienda_top} con un total de ${ingreso_top:,.2f}')
# Out:
# 🏆 La tienda con mayor ingreso es Tienda 1 con un total de $1,150,880,400.00

# %%
# Encontrar la tienda con el menor ingreso
tienda_menor = min(ingresos, key=ingresos.get)
ingreso_menor = ingresos[tienda_menor]

# Mostrar resultado
print(f' La tienda con menor ingreso es {tienda_menor} con un total de ${ingreso_menor:,.2f}')
# Out:
#  La tienda con menor ingreso es Tienda 4 con un total de $1,038,375,700.00

# %%
# Calcular el promedio de ingresos
promedio_ingreso = sum(ingresos.values()) / len(ingresos)

# Mostrar el resultado
print(f'📊 Promedio de ingreso entre las 4 tiendas: ${promedio_ingreso:,.2f}')
# Out:
# 📊 Promedio de ingreso entre las 4 tiendas: $1,100,904,800.00

# %% [markdown]
# ahora la segunda parte del challenge

# %%
print(df_tienda1.columns)
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
# Función para mostrar productos vendidos por categoría sin gráficos ni metadata
def productos_por_categoria(df, nombre_tienda):
    conteo = df['Categoría del Producto'].value_counts()
    print(f"\n📊 Categorías más populares en {nombre_tienda}:\n")
    for categoria, cantidad in conteo.items():
        print(f"{categoria}: {cantidad}")


# Ejecutar para cada tienda
productos_por_categoria(df_tienda1, 'Tienda 1')
productos_por_categoria(df_tienda2, 'Tienda 2')
productos_por_categoria(df_tienda3, 'Tienda 3')
productos_por_categoria(df_tienda4, 'Tienda 4')
# Out:
# 📊 Categorías más populares en Tienda 1:
#
# Muebles: 465
# Electrónicos: 448
# Juguetes: 324
# Electrodomésticos: 312
# Deportes y diversión: 284
# Instrumentos musicales: 182
# Libros: 173
# Artículos para el hogar: 171
#
# 📊 Categorías más populares en Tienda 2:
#
# Muebles: 442
# Electrónicos: 422
# Juguetes: 313
# Electrodomésticos: 305
# Deportes y diversión: 275
# Instrumentos musicales: 224
# Libros: 197
# Artículos para el hogar: 181
#
# 📊 Categorías más populares en Tienda 3:
#
# Muebles: 499
# Electrónicos: 451
# Juguetes: 315
# Electrodomésticos: 278
# Deportes y diversión: 277
# Libros: 185
# Instrumentos musicales: 177
# Artículos para el hogar: 177
#
# 📊 Categorías más populares en Tienda 4:
#
# Muebles: 480
# Electrónicos: 451
# Juguetes: 338
# Deportes y diversión: 277
# Electrodomésticos: 254
# Artículos para el hogar: 201
# Libros: 187
# Instrumentos musicales: 170

# %% [markdown]
# tercera parte de challenge

# %%
# Calcular calificación promedio por tienda
calificacion_t1 = df_tienda1['Calificación'].mean()
calificacion_t2 = df_tienda2['Calificación'].mean()
calificacion_t3 = df_tienda3['Calificación'].mean()
calificacion_t4 = df_tienda4['Calificación'].mean()

# Mostrar los resultados formateados
print(f'⭐ Calificación promedio Tienda 1: {calificacion_t1:.2f}')
print(f'⭐ Calificación promedio Tienda 2: {calificacion_t2:.2f}')
print(f'⭐ Calificación promedio Tienda 3: {calificacion_t3:.2f}')
print(f'⭐ Calificación promedio Tienda 4: {calificacion_t4:.2f}')
# Out:
# ⭐ Calificación promedio Tienda 1: 3.98
# ⭐ Calificación promedio Tienda 2: 4.04
# ⭐ Calificación promedio Tienda 3: 4.05
# ⭐ Calificación promedio Tienda 4: 4.00

# %% [markdown]
# cuarta parte del challenge

# %%
# Función para identificar los productos más y menos vendidos por tienda
def productos_destacados(df, nombre_tienda):
    conteo = df['Producto'].value_counts()

    producto_top = conteo.idxmax()      # Producto más vendido
    cantidad_top = conteo.max()

    producto_min = conteo.idxmin()      # Producto menos vendido
    cantidad_min = conteo.min()

    print(f"\n🛒 {nombre_tienda}")
    print(f"🔝 Producto más vendido: {producto_top} ({cantidad_top} ventas)")
    print(f"🔻 Producto menos vendido: {producto_min} ({cantidad_min} venta{'s' if cantidad_min > 1 else ''})")

# Ejecutar para cada tienda
productos_destacados(df_tienda1, 'Tienda 1')
productos_destacados(df_tienda2, 'Tienda 2')
productos_destacados(df_tienda3, 'Tienda 3')
productos_destacados(df_tienda4, 'Tienda 4')
# Out:
# 🛒 Tienda 1
# 🔝 Producto más vendido: Microondas (60 ventas)
# 🔻 Producto menos vendido: Auriculares con micrófono (33 ventas)
#
# 🛒 Tienda 2
# 🔝 Producto más vendido: Iniciando en programación (65 ventas)
# 🔻 Producto menos vendido: Juego de mesa (32 ventas)
#
# 🛒 Tienda 3
# 🔝 Producto más vendido: Kit de bancas (57 ventas)
# 🔻 Producto menos vendido: Bloques de construcción (35 ventas)
#
# 🛒 Tienda 4
# 🔝 Producto más vendido: Cama box (62 ventas)
# 🔻 Producto menos vendido: Guitarra eléctrica (33 ventas)

# %% [markdown]
# Quibta parte del challenge

# %%
# Calcular el costo de envío promedio para cada tienda
envio_t1 = df_tienda1['Costo de envío'].mean()
envio_t2 = df_tienda2['Costo de envío'].mean()
envio_t3 = df_tienda3['Costo de envío'].mean()
envio_t4 = df_tienda4['Costo de envío'].mean()

# Mostrar los resultados formateados
print(f'📦 Costo de envío promedio Tienda 1: ${envio_t1:,.2f}')
print(f'📦 Costo de envío promedio Tienda 2: ${envio_t2:,.2f}')
print(f'📦 Costo de envío promedio Tienda 3: ${envio_t3:,.2f}')
print(f'📦 Costo de envío promedio Tienda 4: ${envio_t4:,.2f}')
# Out:
# 📦 Costo de envío promedio Tienda 1: $26,018.61
# 📦 Costo de envío promedio Tienda 2: $25,216.24
# 📦 Costo de envío promedio Tienda 3: $24,805.68
# 📦 Costo de envío promedio Tienda 4: $23,459.46

# %% [markdown]
# Gráficos

# %%
# ✅ Preparar listas de datos
tiendas = list(ingresos.keys())
valores = list(ingresos.values())

# ✅ Crear gráfico de barras
plt.figure(figsize=(8, 5))
barras = plt.bar(tiendas, valores, color='skyblue')

# ✅ Agregar etiquetas encima de cada barra
for i, barra in enumerate(barras):
    altura = barra.get_height()
    plt.text(barra.get_x() + barra.get_width() / 2,
             altura + max(valores) * 0.01,
             f"${valores[i]:,.0f}",
             ha='center', va='bottom', fontsize=10)

# ✅ Títulos y ejes
plt.title('Ingreso total por tienda')
plt.xlabel('Tienda')
plt.ylabel('Ingreso total ($)')
plt.tight_layout()
plt.show()

# %%
# Función para graficar las categorías más vendidas de una tienda
def graficar_categorias(df, nombre_tienda):
    conteo = df['Categoría del Producto'].value_counts()

    plt.figure(figsize=(10, 5))
    conteo.plot(kind='barh', color='skyblue')
    plt.title(f' {nombre_tienda} – Productos vendidos por categoría')
    plt.xlabel('Cantidad de productos vendidos')
    plt.ylabel('Categoría')
    plt.tight_layout()
    plt.show()

# Ejecutar para cada tienda
graficar_categorias(df_tienda1, 'Tienda 1')
graficar_categorias(df_tienda2, 'Tienda 2')
graficar_categorias(df_tienda3, 'Tienda 3')
graficar_categorias(df_tienda4, 'Tienda 4')

# %%
# Función para graficar los productos más vendidos de una tienda
def graficar_productos_top(df, nombre_tienda, top_n=10):
    conteo = df['Producto'].value_counts().head(top_n)

    plt.figure(figsize=(10, 5))
    conteo.plot(kind='barh', color='skyblue')
    plt.title(f'{nombre_tienda} – Top {top_n} productos más vendidos')
    plt.xlabel('Cantidad de ventas')
    plt.ylabel('Producto')
    plt.gca().invert_yaxis()  # Mostrar el producto más vendido arriba
    plt.tight_layout()
    plt.show()

# Ejecutar para cada tienda
graficar_productos_top(df_tienda1, 'Tienda 1')
graficar_productos_top(df_tienda2, 'Tienda 2')
graficar_productos_top(df_tienda3, 'Tienda 3')
graficar_productos_top(df_tienda4, 'Tienda 4')

# %%
ingresos_totales = [df_tienda1['Precio'].sum(), df_tienda2['Precio'].sum(), df_tienda3['Precio'].sum(), df_tienda4['Precio'].sum()]
calificaciones_prom = [df_tienda1['Calificación'].mean(), df_tienda2['Calificación'].mean(), df_tienda3['Calificación'].mean(), df_tienda4['Calificación'].mean()]
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# Crear gráfico
plt.figure(figsize=(10, 7))
plt.scatter(ingresos_totales, calificaciones_prom, s=100, color='skyblue')

# Etiquetas en cada punto
for i in range(len(tiendas)):
    plt.text(ingresos_totales[i], calificaciones_prom[i] + 0.00099, tiendas[i], ha='center', fontsize=10, weight='bold')

# Ejes y título
plt.title(' Ingreso vs Calificación promedio por tienda')
plt.xlabel('Ingreso total ($)')
plt.ylabel('Calificación promedio')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# extra

# %%
# Función para graficar la ubicación de ventas por tienda
def mapa_ventas(df, nombre_tienda):
    plt.figure(figsize=(10, 7))
    plt.scatter(df['lon'], df['lat'], alpha=0.5, color='teal')
    plt.title(f' Distribución geográfica de ventas – {nombre_tienda}')
    plt.xlabel('Longitud')
    plt.ylabel('Latitud')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Ejecutar para cada tienda
mapa_ventas(df_tienda1, 'Tienda 1')
mapa_ventas(df_tienda2, 'Tienda 2')
mapa_ventas(df_tienda3, 'Tienda 3')
mapa_ventas(df_tienda4, 'Tienda 4')

# %% [markdown]
# Informe textual

# %% [markdown]
# Con el propósito de financiar un nuevo emprendimiento, el Sr. Juan está considerando vender una de las cuatro tiendas que conforman su cadena comercial Alura Store. Para tomar una decisión informada, se ha realizado un análisis integral que abarca variables clave como los ingresos totales, el volumen de ventas por categoría, productos destacados, costos de envío y la calificación promedio otorgada por los clientes. Este informe tiene como objetivo identificar cuál de las tiendas presenta el menor nivel de eficiencia y, por tanto, representa la mejor opción para ser vendida.
#
# En primer lugar, se evaluaron los ingresos generados por cada tienda. Los resultados muestran que la Tienda 1 lidera con un ingreso total de 1,150,880,400.00, seguida por la tienda 2 con un total de 1,116,343,500.00 y la Tienda 3 con 1,098,019,600.00. Por su parte la tienda 4 registra el menor ingreso con un aproximado de $1,038,375,700.00, lo cual representa una diferencia de más de 62 millones de colones respecto al promedio general entre tiendas. Esta diferencia inicial ya posiciona a la Tienda 4 como la opción menos rentable dentro del portafolio.
#
# No obstante, el análisis no se limita únicamente a los ingresos. También se examinó el volumen de ventas por categoría. En este aspecto, todas las tiendas muestran un comportamiento relativamente homogéneo, con un enfoque claro en productos de alta demanda como muebles, electrónicos y juguetes. La Tienda 3, por ejemplo, lidera en ventas de muebles con 499 unidades, mientras que la Tienda 4 también mantiene cifras elevadas con 480 muebles vendidos y 451 artículos electrónicos. Sin embargo, a pesar de su buen desempeño en volumen de productos, la Tienda 4 continúa generando el menor nivel de ingresos, lo que sugiere que sus márgenes de ganancia por unidad podrían ser más bajos, o que su estrategia de precios no es la más adecuada.
#
# Al observar los productos más y menos vendidos, se encuentra que no hay grandes diferencias entre tiendas. En la Tienda 4, por ejemplo, el producto más vendido es la cama box con 62 unidades, mientras que el menos vendido es la guitarra eléctrica con 33. Esta similitud en el comportamiento de ventas indica que el problema no radica en la diversidad o atractivo del catálogo de productos, sino en la capacidad de conversión en términos de ingresos.
#
# Un factor adicional considerado en este estudio fue el costo promedio de envío. Aquí se identificó que la Tienda 4 es la más eficiente operativamente, con un costo promedio de envío de $23,459.46, inferior al de las otras tiendas. Sin embargo, esta ventaja logística no se traduce en una mayor rentabilidad ni compensa sus menores ingresos, lo que refuerza la hipótesis de una eficiencia global reducida.
#
# Finalmente, se tomó en cuenta la calificación promedio que los clientes otorgan a cada tienda. La Tienda 3 tiene la mejor calificación con 4.05, seguida por la Tienda 2 con 4.04, y la Tienda 4 con 4.00. Aunque esta última no presenta una mala valoración, tampoco destaca, especialmente si se considera que Tienda 1, con la calificación más baja (3.98), es al mismo tiempo la más rentable. Esto demuestra que una buena percepción del cliente, si no está acompañada de un modelo financiero eficiente, no garantiza sostenibilidad.
#
# En conjunto, los resultados del análisis sugieren que la Tienda 4 es la menos eficiente de las cuatro. A pesar de mostrar buen volumen de ventas y contar con costos de envío bajos, no logra traducir estos elementos en ingresos sólidos ni en una calificación superior. Su rentabilidad general es la más débil, lo que la convierte en la mejor candidata para ser vendida.
#
# Por lo tanto, se recomienda al Sr. Juan considerar la venta de la Tienda 4. Esta decisión permitiría liberar recursos sin afectar de forma significativa el rendimiento global de la cadena, y aportaría capital inicial para emprender un nuevo proyecto con mayores perspectivas de crecimiento
